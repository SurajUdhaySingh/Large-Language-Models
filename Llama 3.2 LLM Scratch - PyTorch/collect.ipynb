# %%
import download_corpus as d

# %%
titles = [
        "Python (programming language)",
        "Beautiful Soup (HTML parser)",
        "Web scraping",
        "Python (programming language)",
        "Artificial intelligence",
        "Machine learning"
]

d.download_wiki_articles(article_titles=titles, output_file="test_corpus.txt")
# Out:
# Successfully downloaded Python (programming language)
# Successfully downloaded Beautiful Soup (HTML parser)
# Successfully downloaded Web scraping
# Successfully downloaded Python (programming language)
# Successfully downloaded Artificial intelligence
# Successfully downloaded Machine learning
#
# All articles processed. Output saved to test_corpus.txt

# %%
ai_wikipedia_articles = [
    # Core AI Concepts
    "Artificial intelligence",
    "Strong AI",
    "Weak AI",
    "General artificial intelligence",
    "Machine intelligence",
    "Cognitive computing",
    "Knowledge representation and reasoning",
    "Automated reasoning",
    "Symbolic AI",
    "Sub-symbolic AI",
    "Artificial consciousness",
    "Explainable artificial intelligence",
    
    # Machine Learning
    "Machine learning",
    "Supervised learning",
    "Unsupervised learning",
    "Reinforcement learning",
    "Deep learning",
    "Feature learning",
    "Transfer learning",
    "Federated learning",
    "Online machine learning",
    "Batch learning",
    "Active learning (machine learning)",
    "Semi-supervised learning",
    
    # Deep Learning and Neural Networks
    "Artificial neural network",
    "Convolutional neural network",
    "Recurrent neural network",
    "Long short-term memory",
    "Generative adversarial network",
    "Transformer (machine learning model)",
    "Deep belief network",
    "Autoencoder",
    "Neural Turing machine",
    "Spiking neural network",
    "Capsule neural network",
    
    # AI Algorithms and Techniques
    "Decision tree learning",
    "Random forest",
    "Support-vector machine",
    "K-nearest neighbors algorithm",
    "Naive Bayes classifier",
    "Gradient boosting",
    "XGBoost",
    "LightGBM",
    "CatBoost",
    "Bayesian network",
    "Hidden Markov model",
    "Genetic algorithm",
    "Evolutionary computation",
    "Swarm intelligence",
    "Particle swarm optimization",
    "Ant colony optimization",
    
    # Natural Language Processing
    "Natural language processing",
    "Natural language understanding",
    "Natural language generation",
    "Sentiment analysis",
    "Machine translation",
    "Word embedding",
    "BERT (language model)",
    "GPT-3",
    "Chatbot",
    "Question answering",
    "Text mining",
    "Speech recognition",
    "Speech synthesis",
    
    # Computer Vision
    "Computer vision",
    "Image recognition",
    "Object detection",
    "Facial recognition system",
    "Optical character recognition",
    "Image segmentation",
    "Pose estimation",
    "Visual odometry",
    "3D reconstruction",
    
    # Robotics and AI
    "Robotics",
    "Autonomous robot",
    "Human–robot interaction",
    "Robot learning",
    "Swarm robotics",
    "Soft robotics",
    "Robotic process automation",
    
    # AI Ethics and Society
    "AI ethics",
    "Bias in artificial intelligence",
    "AI safety",
    "Existential risk from artificial general intelligence",
    "Algorithmic bias",
    "AI governance",
    "Privacy in artificial intelligence",
    "AI alignment",
    "Value alignment",
    "Machine ethics",
    "AI takeover",
    "Technological unemployment",
    
    # AI Applications
    "AI in healthcare",
    "AI in finance",
    "AI in education",
    "AI in agriculture",
    "AI in transportation",
    "Autonomous vehicle",
    "AI in gaming",
    "AI in cybersecurity",
    "AI in marketing",
    "AI in law",
    "AI in manufacturing",
    "Predictive maintenance",
    "Recommender system",
    
    # AI History and Pioneers
    "History of artificial intelligence",
    "AI winter",
    "Turing test",
    "Dartmouth Conference",
    "Expert system",
    "Alan Turing",
    "John McCarthy (computer scientist)",
    "Marvin Minsky",
    "Herbert Simon",
    "Geoffrey Hinton",
    "Yann LeCun",
    "Yoshua Bengio",
    "Andrew Ng",
    
    # AI Tools and Frameworks
    "TensorFlow",
    "PyTorch",
    "Keras",
    "Scikit-learn",
    "OpenAI",
    "Hugging Face",
    "Jupyter Notebook",
    "Apache Spark",
    
    # Knowledge and Reasoning
    "Expert system",
    "Knowledge graph",
    "Semantic web",
    "Ontology (information science)",
    "Reasoning system",
    "Logic programming",
    "Prolog",
    
    # AI and Data
    "Big data",
    "Data mining",
    "Data science",
    "Feature engineering",
    "Data augmentation",
    "Synthetic data",
    
    # Emerging AI Trends
    "Quantum machine learning",
    "Neuromorphic computing",
    "Edge AI",
    "TinyML",
    "AI accelerator",
    "Graph neural network",
    "Self-supervised learning",
    "Meta-learning",
    
    # AI in Science and Research
    "AI for scientific discovery",
    "AlphaFold",
    "AI in astronomy",
    "AI in physics",
    "AI in chemistry",
    "AI in biology",
    
    # Miscellaneous AI Topics
    "Cognitive architecture",
    "Embodied AI",
    "Affective computing",
    "Computational creativity",
    "AI-complete",
    "Friendly artificial intelligence",
    "Superintelligence",
    "Technological singularity"
]

d.download_wiki_articles(article_titles=ai_wikipedia_articles, output_file="ai_corpus.txt")
# Out:
# Successfully downloaded Artificial intelligence
# Successfully downloaded Strong AI
# Successfully downloaded Weak AI
# Successfully downloaded General artificial intelligence
# Successfully downloaded Machine intelligence
# Successfully downloaded Cognitive computing
# Successfully downloaded Knowledge representation and reasoning
# Successfully downloaded Automated reasoning
# Successfully downloaded Symbolic AI
# Successfully downloaded Sub-symbolic AI
# Successfully downloaded Artificial consciousness
# Successfully downloaded Explainable artificial intelligence
# Successfully downloaded Machine learning
# Successfully downloaded Supervised learning
# Successfully downloaded Unsupervised learning
# Successfully downloaded Reinforcement learning
# Successfully downloaded Deep learning
# Successfully downloaded Feature learning
# Successfully downloaded Transfer learning
# Successfully downloaded Federated learning
# Successfully downloaded Online machine learning
# ...

# %%
historical_wikipedia_articles = [
    # Ancient History
    "Ancient Egypt",
    "Mesopotamia",
    "Indus Valley Civilisation",
    "Ancient Greece",
    "Ancient Rome",
    "Hittites",
    "Phoenicia",
    "Persian Empire",
    "Alexander the Great",
    "Cleopatra",
    "Pyramids of Giza",
    "Stonehenge",
    "Bronze Age",
    "Iron Age",
    
    # Classical History
    "Peloponnesian War",
    "Punic Wars",
    "Roman Republic",
    "Roman Empire",
    "Julius Caesar",
    "Augustus",
    "Hannibal",
    "Spartacus",
    "Battle of Thermopylae",
    "Fall of the Western Roman Empire",
    
    # Medieval History
    "Middle Ages",
    "Byzantine Empire",
    "Islamic Golden Age",
    "Crusades",
    "Magna Carta",
    "Black Death",
    "Viking Age",
    "Norman Conquest",
    "Feudalism",
    "Charlemagne",
    "William the Conqueror",
    "Battle of Hastings",
    "Hundred Years' War",
    "Joan of Arc",
    
    # Early Modern History
    "Renaissance",
    "Reformation",
    "Age of Exploration",
    "Christopher Columbus",
    "Spanish Inquisition",
    "Thirty Years' War",
    "Tudor period",
    "Elizabeth I",
    "Ottoman Empire",
    "Ming Dynasty",
    "Tokugawa shogunate",
    "Scientific Revolution",
    "Galileo Galilei",
    
    # Modern History
    "American Revolution",
    "French Revolution",
    "Napoleon Bonaparte",
    "Industrial Revolution",
    "American Civil War",
    "World War I",
    "Russian Revolution",
    "Great Depression",
    "World War II",
    "Holocaust",
    "Cold War",
    "Vietnam War",
    "Civil Rights Movement",
    "Apartheid",
    
    # Historical Figures
    "Leonardo da Vinci",
    "Michelangelo",
    "Queen Victoria",
    "Abraham Lincoln",
    "Winston Churchill",
    "Mahatma Gandhi",
    "Martin Luther King Jr.",
    "Nelson Mandela",
    "Catherine the Great",
    "Genghis Khan",
    "Suleiman the Magnificent",
    "Thomas Jefferson",
    
    # Ancient Civilizations and Cultures
    "Maya civilization",
    "Aztec",
    "Inca Empire",
    "Ancient China",
    "Harappan civilization",
    "Sumer",
    "Babylon",
    "Assyria",
    "Etruscan civilization",
    "Kushite Kingdom",
    
    # Historical Events
    "Fall of Constantinople",
    "Discovery of the New World",
    "Boston Tea Party",
    "Storming of the Bastille",
    "Battle of Waterloo",
    "D-Day",
    "Berlin Wall",
    "Moon Landing",
    "End of Apartheid",
    "Fall of the Soviet Union",
    
    # Historical Concepts and Themes
    "Slavery",
    "Colonialism",
    "Imperialism",
    "Enlightenment",
    "Feminism",
    "Industrialization",
    "Decolonization",
    "Globalization",
    "Historiography",
    "Oral history",
    
    # Regional Histories
    "History of India",
    "History of China",
    "History of Japan",
    "History of Africa",
    "History of the Middle East",
    "History of Latin America",
    "History of Australia",
    "History of Canada",
    "History of Mexico",
    "History of Russia",
    
    # Archaeological Sites and Artifacts
    "Terracotta Army",
    "Rosetta Stone",
    "Dead Sea Scrolls",
    "Pompeii",
    "Machu Picchu",
    "Great Wall of China",
    "Colosseum",
    "Acropolis of Athens",
    "Tomb of Tutankhamun",
    
    # Miscellaneous Historical Topics
    "Medieval warfare",
    "Renaissance art",
    "Age of Sail",
    "Piracy",
    "Silk Road",
    "Mansa Musa",
    "Mongol Empire",
    "Spanish Armada",
    "Treaty of Versailles",
    "Cuban Missile Crisis"
]

d.download_wiki_articles(article_titles=historical_wikipedia_articles, output_file="history_corpus.txt")
# Out:
# Successfully downloaded Ancient Egypt
# Successfully downloaded Mesopotamia
# Successfully downloaded Indus Valley Civilisation
# Successfully downloaded Ancient Greece
# Successfully downloaded Ancient Rome
# Successfully downloaded Hittites
# Successfully downloaded Phoenicia
# Successfully downloaded Persian Empire
# Successfully downloaded Alexander the Great
# Successfully downloaded Cleopatra
# Successfully downloaded Pyramids of Giza
# Successfully downloaded Stonehenge
# Successfully downloaded Bronze Age
# Successfully downloaded Iron Age
# Successfully downloaded Peloponnesian War
# Successfully downloaded Punic Wars
# Successfully downloaded Roman Republic
# Successfully downloaded Roman Empire
# Successfully downloaded Julius Caesar
# Successfully downloaded Augustus
# Successfully downloaded Hannibal
# Successfully downloaded Spartacus
# Successfully downloaded Battle of Thermopylae
# Successfully downloaded Fall of the Western Roman Empire
# ...

# %%
basic_concepts_wikipedia_articles = [
    # Basic Human Concepts
    "Human",
    "Consciousness",
    "Emotion",
    "Memory",
    "Language",
    "Communication",
    "Thought",
    "Reasoning",
    "Imagination",
    "Identity",
    "Culture",
    "Society",
    "Family",
    "Community",
    "Tradition",
    
    # Knowledge About the Universe
    "Universe",
    "Big Bang",
    "Galaxy",
    "Star",
    "Planet",
    "Black hole",
    "Nebula",
    "Cosmology",
    "Dark matter",
    "Dark energy",
    "Astronomy",
    "Astrophysics",
    "Solar System",
    "Milky Way",
    "Exoplanet",
    
    # Our World (Earth)
    "Earth",
    "Geology",
    "Plate tectonics",
    "Volcano",
    "Earthquake",
    "Mountain",
    "Ocean",
    "Continent",
    "Climate",
    "Weather",
    "Atmosphere",
    "Hydrology",
    "Ecosystem",
    "Biodiversity",
    "Natural resource",
    
    # Human Cultures
    "Anthropology",
    "Ethnography",
    "Ritual",
    "Mythology",
    "Religion",
    "Philosophy",
    "Art",
    "Music",
    "Dance",
    "Literature",
    "Cuisine",
    "Clothing",
    "Architecture",
    "Festivals",
    "Customs",
    
    # Environment and Nature
    "Ecology",
    "Forest",
    "Desert",
    "Rainforest",
    "Tundra",
    "Savanna",
    "Coral reef",
    "Wildlife",
    "Endangered species",
    "Conservation",
    "Pollution",
    "Climate change",
    "Renewable energy",
    "Sustainability",
    "Global warming",
    
    # Basic Science and Knowledge
    "Physics",
    "Chemistry",
    "Biology",
    "Mathematics",
    "Time",
    "Space",
    "Energy",
    "Matter",
    "Force",
    "Gravity",
    "Evolution",
    "Genetics",
    "Cell (biology)",
    "DNA",
    "Ecosystem",
    
    # Human Experience and Behavior
    "Psychology",
    "Sociology",
    "Ethics",
    "Morality",
    "Love",
    "Friendship",
    "Conflict",
    "Cooperation",
    "Education",
    "Knowledge",
    "Belief",
    "Creativity",
    "Curiosity",
    "Happiness",
    "Fear",
    
    # World Geography and Peoples
    "Africa",
    "Asia",
    "Europe",
    "North America",
    "South America",
    "Australia",
    "Antarctica",
    "Population",
    "Migration",
    "Urbanization",
    "Rural area",
    "Indigenous peoples",
    "Nomad",
    "Tribe",
    "Civilization",
    
    # Natural Phenomena
    "Aurora",
    "Tsunami",
    "Hurricane",
    "Tornado",
    "Lightning",
    "Rainbow",
    "Tide",
    "Season",
    "Solar eclipse",
    "Lunar eclipse",
    "Meteor shower",
    "Comet",
    "Asteroid",
    "Geothermal energy",
    "Fossil",
    
    # Environment and Technology
    "Agriculture",
    "Irrigation",
    "Deforestation",
    "Reforestation",
    "Water cycle",
    "Carbon cycle",
    "Ozone layer",
    "Greenhouse effect",
    "Recycling",
    "Biotechnology",
    "Environmental science",
    "Wildfire",
    "Flood",
    "Drought",
    "Erosion"
]

d.download_wiki_articles(article_titles=basic_concepts_wikipedia_articles, output_file="basic_knowledge_corpus.txt")
# Out:
# Successfully downloaded Human
# Successfully downloaded Consciousness
# Successfully downloaded Emotion
# Successfully downloaded Memory
# Successfully downloaded Language
# Successfully downloaded Communication
# Successfully downloaded Thought
# Successfully downloaded Reasoning
# Successfully downloaded Imagination
# Successfully downloaded Identity
# Successfully downloaded Culture
# Successfully downloaded Society
# Successfully downloaded Family
# Successfully downloaded Community
# Successfully downloaded Tradition
# Successfully downloaded Universe
# Successfully downloaded Big Bang
# Successfully downloaded Galaxy
# Successfully downloaded Star
# Successfully downloaded Planet
# Successfully downloaded Black hole
# Successfully downloaded Nebula
# Successfully downloaded Cosmology
# Successfully downloaded Dark matter
# Successfully downloaded Dark energy
# Successfully downloaded Astronomy
# Successfully downloaded Astrophysics
# Successfully downloaded Solar System
# ...
